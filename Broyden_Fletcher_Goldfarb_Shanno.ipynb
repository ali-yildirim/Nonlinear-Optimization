# %%
import numpy as np
from numpy.linalg import norm, inv
import pandas as pd

# %%
# define the first function of interest
def f(x):
    return (5 * x[0] - x[1])**4 + (x[0] - 2)**2 + x[0] - 2*x[1] + 12

# define the gradient of the said function
def gradient(x):
    dx1 = 20 * ( 5 * x[0] - x[1])**3 + 2 * (x[0] - 2) + 1
    dx2 = -4 * ( 5 * x[0] - x[1])**3 - 2
    return np.array([dx1, dx2])

# define Rosenbrock’s curved valley function.
def rosenbrock(x):
    return 100*np.power(x[1]-np.power(x[0],2),2) + np.power(1-x[0],2)

# define its gradient
def gradient_rosenbrok(x):
    dx1 = 400*(np.power(x[0],3) - x[0]*x[1]) + 2 * (x[0]-1)
    dx2 = 200*(x[1]-np.power(x[0],2))
    return np.array([dx1, dx2])

# to be used for line search
# parameter set  (ϵ2, a, b) = (0.005,-100, 100)
def Golden_Section(f, a=-100, b=100, epsilon=0.005):
    gamma = (1 + np.sqrt(5))/2
    c = 1/gamma

    x = b - c*(b-a) # defining the x0
    y = a + c*(b-a) # defining the y0

    fx = f(x)       # defining the f(x0)
    fy = f(y)       # defining the f(y0)

    while abs(b-a) > epsilon:
        if fx > fy:
            a = x
            x = y
            fx = fy

            y = a + c*(b-a)
            fy = f(y)

        else:
            b = y
            y = x
            fy = fx

            x = b - c*(b-a)
            fx = f(x)

    return x

# %%
def BFGS(function, gradient, x0, epsilon=1e-6):

    # lists to keep track of the variables
    x_list, f_list, d_list, alpha_list, xnew_list = [], [], [], [], []

    f, grad_f = function, gradient

    n = len(x0)
    x = np.array(x0, dtype=float)
    H = np.eye(n)  # H0 = I
    g = grad_f(x)

    # do until || ∇f(x) || <= ϵ1, i.e. until gradient diminishes
    while norm(g) > epsilon:
        g = grad_f(x) # gradient at the current point
        x_list.append(x)
        f_list.append(f(x))

        # Search direction
        d = -H.dot(g)
        d_list.append(d)

        # Line search

        def h(a): return f(x + a * d)  # h(α) = f(x + α*d),
        alpha = Golden_Section(h) # α = argmin h(α)
        alpha_list.append(alpha)

        # Update position
        x_new = x + alpha * d
        xnew_list.append(x_new)

        # Compute difference vectors
        sk = x_new - x
        yk = grad_f(x_new) - g

        # H(k+1)
        H = H + (sk.reshape(1, 2) @ yk.reshape(2, 1) + yk.reshape(1, 2) @ H @ yk.reshape(2, 1)) * sk.reshape(2, 1) @ sk.reshape(1, 2) / (sk.reshape(1, 2) @ yk.reshape(2, 1))**2 \
              - (H @ yk.reshape(2, 1) @ sk.reshape(1, 2) + sk.reshape(2, 1) @ yk.reshape(1, 2) @ H) / (sk.reshape(1, 2) @ yk.reshape(2, 1))

        # update x
        x = x_new

    return pd.DataFrame({'x(k)': x_list, 'f(x(k))': f_list, 'd(k)': d_list, 'alpha(k)': alpha_list, 'x(k+1)': xnew_list}).rename_axis('k')

# %% [markdown]
# $
# \text{
# }
# $

# %% [markdown]
# $
# \text{
# }
# $

# %% [markdown]
# $$
# (\epsilon_1, x^{(0)}) = (1e-6, (0, 0))
# $$

# %%
x0 = np.array([0.0, 0.0])
BFGS(f, gradient, x0)
# Out:
#                                          x(k)    f(x(k))  \
# k
# 0                                  [0.0, 0.0]  16.000000
# 1  [0.14061287713497048, 0.09374191808998032]  15.548294
# 2     [6.036821235065613, 31.276405707141734] -26.796533
# 3     [6.213092539551369, 31.817846590360414] -27.352004
# 4     [6.5045621472823925, 33.30436652678602] -27.439978
# 5      [6.500212757928666, 33.29478457485708] -27.440551
# 6      [6.500000242586265, 33.29370144944281] -27.440551
# 7     [6.500000015977674, 33.293700589160714] -27.440551
#
#                                                 d(k)  alpha(k)  \
# k
# 0                                         [3.0, 2.0]  0.046871
# 1           [0.9166458414032581, 4.8477695072739975]  6.432373
# 2           [1.0358127262612402, 3.1816373004793435]  0.170177
# 3            [0.3134900823680373, 1.598826241059889]  0.929757
# 4    [-0.0031800511171972386, -0.007005833338520147]  1.367711
# 5    [-0.00021314280007115943, -0.00108632337326606]  0.997056
# 6  [-2.4423554465826647e-07, -9.271999171958773e-07]  0.927828
# 7  [-1.5978903994107714e-08, -6.318302527153341e-08] -1.317491
#
#                                        x(k+1)
# k
# 0  [0.14061287713497048, 0.09374191808998032]
# 1     [6.036821235065613, 31.276405707141734]
# 2     [6.213092539551369, 31.817846590360414]
# 3     [6.5045621472823925, 33.30436652678602]
# 4      [6.500212757928666, 33.29478457485708]
# 5      [6.500000242586265, 33.29370144944281]
# 6     [6.500000015977674, 33.293700589160714]
# 7     [6.500000037029732, 33.293700672403766]

# %% [markdown]
# $$
# (\epsilon_1, x^{(0)}) = (5e-8, (3, 3))
# $$

# %%
x0 = np.array([3.0, 3.0])
BFGS(f, gradient, x0, epsilon=5e-8)
# Out:
#                                            x(k)      f(x(k))  \
# k
# 0                                   [1.0, -1.0]  1312.000000
# 1   [0.016630085298312114, -0.8028251108748179]    18.172187
# 2        [6.54909316204318, 32.053346866052145]   -24.633884
# 3         [6.403147620893014, 32.8069038235775]   -27.431146
# 4        [6.498039184262831, 33.28975536766382]   -27.440417
# 5       [6.500000170493812, 33.293708467673845]   -27.440551
# 6         [6.499999998882277, 33.2937005356635]   -27.440551
# 7         [6.5000000001277, 33.293700524880364]   -27.440551
# 8        [6.500000000661833, 33.29370052026371]   -27.440551
# 9       [6.500000001318863, 33.293700514584835]   -27.440551
# 10      [6.500000001418098, 33.293700513727124]   -27.440551
# 11       [6.500000003290861, 33.29370049754044]   -27.440551
# 12      [6.500000002271269, 33.293700506353005]   -27.440551
# 13        [6.49999999958795, 33.29370052954555]   -27.440551
# 14       [6.499999999976995, 33.29370052618294]   -27.440551
#
#                                                  d(k)   alpha(k)  \
# k
# 0                                    [-4319.0, 866.0]   0.000228
# 1             [0.4960909314403537, 2.495176592367404]  13.167874
# 2       [-0.001968431558078605, 0.010163553365953008]  74.143061
# 3           [0.09626197328929821, 0.4898248146506808]   0.985764
# 4        [0.006568746726958329, 0.013241761896103169]   0.298533
# 5    [-1.7071911250871755e-07, -7.89076192240877e-06]   1.005227
# 6     [1.117853082317319e-09, -9.678613836937007e-09]   1.114120
# 7   [-1.2769944154512703e-10, 1.1037383123363326e-09]  -4.182741
# 8     [-6.618330328150199e-10, 5.720391339620866e-09]  -0.992743
# 9   [-1.3188623477538964e-09, 1.1399269796786767e-08]  -0.075243
# 10   [-1.4181025106072783e-09, 1.225695478472216e-08]  -1.320612
# 11     [-3.290860859552468e-09, 2.84436626601654e-08]   0.309825
# 12    [-2.271268294447778e-09, 1.963109966912158e-08]   1.181419
# 13    [4.120501546750658e-10, -3.561450389065755e-09]   0.944171
# 14   [2.3004460907034862e-11, -1.988391286745698e-10]   5.701165
#
#                                          x(k+1)
# k
# 0   [0.016630085298312114, -0.8028251108748179]
# 1        [6.54909316204318, 32.053346866052145]
# 2         [6.403147620893014, 32.8069038235775]
# 3        [6.498039184262831, 33.28975536766382]
# 4       [6.500000170493812, 33.293708467673845]
# 5         [6.499999998882277, 33.2937005356635]
# 6         [6.5000000001277, 33.293700524880364]
# 7        [6.500000000661833, 33.29370052026371]
# 8       [6.500000001318863, 33.293700514584835]
# 9       [6.500000001418098, 33.293700513727124]
# 10       [6.500000003290861, 33.29370049754044]
# 11      [6.500000002271269, 33.293700506353005]
# 12        [6.49999999958795, 33.29370052954555]
# 13       [6.499999999976995, 33.29370052618294]
# 14      [6.500000000108147, 33.293700525049324]

# %%
BFGS(f, gradient, x0).to_latex()
# Out:
# '\\begin{tabular}{llrlrl}\n\\toprule\n & x(k) & f(x(k)) & d(k) & alpha(k) & x(k+1) \\\\\n\\midrule\n0 & [3. 3.] & 20746.000000 & [-34563.   6914.] & 0.000228 & [-4.86946385  4.57421153] \\\\\n1 & [-4.86946385  4.57421153] & 699702.041862 & [7.65437094 0.07869799] & 0.766787 & [0.9998083  4.63455612] \\\\\n2 & [0.9998083  4.63455612] & 4.748729 & [0.42308332 2.11546463] & 12.999854 & [ 6.49982982 32.13528796] \\\\\n3 & [ 6.49982982 32.13528796] & -25.504749 & [0.00029455 0.00213639] & 99.998071 & [ 6.52928381 32.34892247] \\\\\n4 & [ 6.52928381 32.34892247] & -25.646316 & [0.10170612 2.0192909 ] & 0.720144 & [ 6.60252684 33.80310215] \\\\\n5 & [ 6.60252684 33.80310215] & -27.430000 & [-0.08290845 -0.40319943] & 1.172055 & [ 6.50535354 33.33053007] \\\\\n6 & [ 6.50535354 33.33053007] & -27.440136 & [-0.02004171 -0.13847177] & 0.262727 & [ 6.50008805 33.29414986] \\\\\n7 & [ 6.50008805 33.29414986] & -27.440551 & [-8.80707223e-05 -4.49323714e-04] & 1.000177 & [ 6.49999996 33.29370046] \\\\\n8 & [ 6.49999996 33.29370046] & -27.440551 & [3.64450261e-08 6.80447584e-08] & 0.681216 & [ 6.49999999 33.2937005 ] \\\\\n9 & [ 6.49999999 33.2937005 ] & -27.440551 & [1.21504484e-08 2.29692319e-08] & 0.538902 & [ 6.49999999 33.29370052] \\\\\n10 & [ 6.49999999 33.29370052] & -27.440551 & [5.60254725e-09 1.05910643e-08] & -0.802138 & [ 6.49999999 33.29370051] \\\\\n\\bottomrule\n\\end{tabular}\n'

# %%
x0 = np.array([0.0, 0.0])
BFGS(rosenbrock, gradient_rosenbrok, x0)
# Out:
#                                            x(k)       f(x(k))  \
# k
# 0                                    [0.0, 0.0]  1.000000e+00
# 1                    [0.15911207650349832, 0.0]  7.711858e-01
# 2     [0.2748357745228913, 0.04408056142881427]  6.247995e-01
# 3     [0.33892860990782725, 0.1258963402396471]  4.491677e-01
# 4     [0.4565571664169125, 0.19270250128771463]  3.201110e-01
# 5       [0.526899202585973, 0.2532045472514102]  2.834493e-01
# 6      [0.8066151856845215, 0.6419858128951756]  4.486653e-02
# 7    [-0.21783834226568566, 0.0595834737169757]  1.497844e+00
# 8      [1.1363439400463595, 1.2915428903321362]  1.859671e-02
# 9   [0.06550974871458015, 0.013024597561095863]  8.808987e-01
# 10   [0.06499822854735549, 0.01234324168684231]  8.808193e-01
# 11  [0.23994637534360722, 0.035661870628860254]  6.256968e-01
# 12   [0.32560396822191995, 0.07361647466668739]  5.597955e-01
# 13    [0.7040037470478522, 0.48633079649229594]  9.624508e-02
# 14    [-0.5061869543908768, 0.2689338024742428]  2.284750e+00
# 15     [1.0651598935699014, 1.1343336592296804]  4.251191e-03
# 16     [1.0643418018411208, 1.1335262932799426]  4.189263e-03
# 17     [1.0201553980747697, 1.0387808194763573]  7.811336e-04
# 18     [1.0027416101355122, 1.0057440216366167]  1.393175e-05
# 19     [1.0002854634227105, 1.0005471888828024]  1.382260e-07
# 20     [0.9999945942057212, 0.9999884694291538]  8.092037e-11
# 21     [1.0000000006190917, 1.0000000005128835]  5.298926e-17
#
#                                                  d(k)   alpha(k)  \
# k
# 0                                         [2.0, -0.0]   0.079556
# 1            [13.778345741464806, 5.2483391581757095]   0.008399
# 2          [0.08800153169897451, 0.11233570506368991]   0.728315
# 3          [0.18334994506835808, 0.10413207746407221]   0.641552
# 4          [0.05760626797744891, 0.04954785591636829]   1.221083
# 5           [0.05917508747489958, 0.0822483046847078]   4.726921
# 6       [-0.04514902662279005, -0.025667244047023082]  22.690490
# 7         [-0.5189425737889548, -0.47210497346803454]  -2.609503
# 8          [0.20833732506592548, 0.24874353407832522]  -5.139906
# 9          [-2.2466170353680788, -2.9925422541039834]   0.000228
# 10        [0.11639576899494049, 0.015514252636095979]   1.503046
# 11          [0.0708036515290554, 0.03137287037747222]   1.209791
# 12          [0.0901720872783568, 0.09834919027742356]   4.196418
# 13      [-0.05384695877949973, -0.009672993654438461]  22.474634
# 14        [-0.5220904594337936, -0.28753486818886165]  -3.009721
# 15         [0.16964277323065385, 0.16741863278548075]  -0.004822
# 16     [-0.021816378780149394, -0.046779166621788014]   2.025378
# 17     [-0.007998781232440822, -0.015174993485749707]   2.177055
# 18     [-0.004774887655327365, -0.010102935803327709]   0.514388
# 19  [-0.00021736723053088973, -0.0004175323244597804]   1.338147
# 20    [5.624357584409127e-06, 1.1995926650120585e-05]   0.961250
# 21   [-6.030290866196583e-10, -4.819903366341427e-10]   1.002106
#
#                                          x(k+1)
# k
# 0                    [0.15911207650349832, 0.0]
# 1     [0.2748357745228913, 0.04408056142881427]
# 2     [0.33892860990782725, 0.1258963402396471]
# 3     [0.4565571664169125, 0.19270250128771463]
# 4       [0.526899202585973, 0.2532045472514102]
# 5      [0.8066151856845215, 0.6419858128951756]
# 6    [-0.21783834226568566, 0.0595834737169757]
# 7      [1.1363439400463595, 1.2915428903321362]
# 8   [0.06550974871458015, 0.013024597561095863]
# 9    [0.06499822854735549, 0.01234324168684231]
# 10  [0.23994637534360722, 0.035661870628860254]
# 11   [0.32560396822191995, 0.07361647466668739]
# 12    [0.7040037470478522, 0.48633079649229594]
# 13    [-0.5061869543908768, 0.2689338024742428]
# 14     [1.0651598935699014, 1.1343336592296804]
# 15     [1.0643418018411208, 1.1335262932799426]
# 16     [1.0201553980747697, 1.0387808194763573]
# 17     [1.0027416101355122, 1.0057440216366167]
# 18     [1.0002854634227105, 1.0005471888828024]
# 19     [0.9999945942057212, 0.9999884694291538]
# 20     [1.0000000006190917, 1.0000000005128835]
# 21     [1.0000000000147924, 1.0000000000298779]

# %%
x0 = np.array([1.0, -1.0])
BFGS(rosenbrock, gradient_rosenbrok, x0, epsilon=1e-10)
# Out:
#                                            x(k)       f(x(k))  \
# k
# 0                                   [1.0, -1.0]  4.000000e+02
# 1     [0.8178522964201551, -0.9089261482100776]  2.489812e+02
# 2      [1.6562304127716536, 1.9397286270200707]  6.497106e+01
# 3       [1.4178649891996047, 2.010980814163802]  1.746521e-01
# 4       [1.334127562346528, 1.7665633426468792]  1.294181e-01
# 5       [1.239185875246302, 1.5181963426569516]  8.743472e-02
# 6       [0.409430539897791, 0.1750302274140083]  3.542436e-01
# 7       [1.9079695404156944, 3.646230910833876]  8.278698e-01
# 8     [-0.7163521241377495, 0.5197370784584106]  2.950190e+00
# 9     [-0.7152572293787886, 0.5091329755000853]  2.942712e+00
# 10   [-0.5201118397206757, 0.22989395778271982]  2.475758e+00
# 11  [-0.3334930035493586, 0.058358106383301744]  2.057616e+00
# 12     [1.0181143044134757, 1.0366832920590663]  3.297296e-04
# 13     [1.0181352705485223, 1.0366589314579637]  3.292421e-04
# 14     [1.0012809532944178, 1.0022399577389791]  1.211187e-05
# 15     [1.0005083174987772, 1.0010285573301296]  2.719914e-07
# 16     [1.0000021773024126, 1.0000034106041389]  9.385527e-11
# 17     [1.0000000438372514, 1.0000000880644233]  1.936908e-15
# 18     [0.9999999999932848, 0.9999999999844637]  4.886097e-22
# 19     [0.9999999999999931, 0.9999999999999841]  4.923478e-28
#
#                                                 d(k)   alpha(k)  \
# k
# 0                                    [-800.0, 400.0]   0.000228
# 1             [45.31969733658014, 153.9880033983467]   0.018499
# 2        [-0.36404252487431943, 0.10881958348619784]   0.654774
# 3    [-0.0016264046097769957, -0.004747240479249991]  51.486221
# 4      [-0.039624550514448374, -0.10365763488944209]   2.396032
# 5      [-0.03164022238093351, -0.051217597248677395]  26.224700
# 6        [-0.24839480179185655, -0.5753792229897549]  -6.032892
# 7          [0.12024557956594926, 0.1432549477303976] -21.824683
# 8         [-0.22704175677664098, 2.1989092056512436]  -0.004822
# 9           [-12.109658447075837, 17.32805030945641]  -0.016115
# 10       [0.07658079362537497, -0.07039134904534818]   2.436888
# 11         [0.0925590025610219, 0.06699638484713288]  14.602656
# 12    [0.001558927441836886, -0.0018113214225741459]   0.013449
# 13  [-0.0009892547670708692, -0.0020202024986150586]  17.037388
# 14  [-0.0006841904389852917, -0.0010727286804393845]   1.129270
# 15  [-0.0005349756124444572, -0.0010835505686394903]   0.946100
# 16  [-2.114256332510986e-06, -3.292624956767212e-06]   1.009085
# 17  [-4.397341711388676e-08, -8.834001832210422e-08]   0.997056
# 18    [6.715096406973105e-12, 1.553628352905588e-11]   0.998985
# 19  [6.8833838544104025e-15, 1.5876191420479046e-14]   0.997056
#
#                                          x(k+1)
# k
# 0     [0.8178522964201551, -0.9089261482100776]
# 1      [1.6562304127716536, 1.9397286270200707]
# 2       [1.4178649891996047, 2.010980814163802]
# 3       [1.334127562346528, 1.7665633426468792]
# 4       [1.239185875246302, 1.5181963426569516]
# 5       [0.409430539897791, 0.1750302274140083]
# 6       [1.9079695404156944, 3.646230910833876]
# 7     [-0.7163521241377495, 0.5197370784584106]
# 8     [-0.7152572293787886, 0.5091329755000853]
# 9    [-0.5201118397206757, 0.22989395778271982]
# 10  [-0.3334930035493586, 0.058358106383301744]
# 11     [1.0181143044134757, 1.0366832920590663]
# 12     [1.0181352705485223, 1.0366589314579637]
# 13     [1.0012809532944178, 1.0022399577389791]
# 14     [1.0005083174987772, 1.0010285573301296]
# 15     [1.0000021773024126, 1.0000034106041389]
# 16     [1.0000000438372514, 1.0000000880644233]
# 17     [0.9999999999932848, 0.9999999999844637]
# 18     [0.9999999999999931, 0.9999999999999841]
# 19                                   [1.0, 1.0]
